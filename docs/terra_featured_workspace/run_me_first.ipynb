# %% [markdown]
# # Install the Baseline Site Selection Tool
#
# The following commands will install the current version of the [Baseline Site Selection Tool](https://github.com/verilylifesciences/metis) on your Terra [detachable persistent disk](https://support.terra.bio/hc/en-us/articles/360047318551-Detachable-Persistent-Disks-).

# %% [markdown]
# ## Install the Python package.

# %%
# %%bash
#
# pip3 install --upgrade --use-feature=2020-resolver \
#   git+https://github.com/verilylifesciences/metis.git

# %% [markdown]
# # Appendix

# %% [markdown]
# ## How to uninstall the Python package

# %% [markdown]
# To uninstall the Metis Python package:
# ```
# pip3 uninstall --yes metis
# ```
